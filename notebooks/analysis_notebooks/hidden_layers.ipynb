# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.ticker import ScalarFormatter
import matplotlib.patches as mpatches

# %%
df_books_3 = pd.read_csv('../../data/results/july_7_results/books_3_bert_hidden.csv')

# %%
df_books_3.head()
# Out:
#    Step  edited_3_books_3_1024_6 - system_level_f1_BERT
# 0     1                                       -0.299176  \
# 1     7                                       -0.301127
# 2    13                                       -0.247370
# 3    19                                       -0.296093
# 4    25                                       -0.292675
#
#    edited_3_books_3_1024_6 - system_level_f1_BERT__MIN
# 0                                          -0.299176    \
# 1                                          -0.301127
# 2                                          -0.247370
# 3                                          -0.296093
# 4                                          -0.292675
#
#    edited_3_books_3_1024_6 - system_level_f1_BERT__MAX
# 0                                          -0.299176    \
# 1                                          -0.301127
# 2                                          -0.247370
# 3                                          -0.296093
# ...

# %%
df_books_3 = df_books_3.drop('Step', axis=1)
df_books_3 = df_books_3.iloc[:, [int(x) for x in range(0, 24, 3)]]

# %%
df_books_3.head()
# Out:
#    edited_3_books_3_1024_6 - system_level_f1_BERT
# 0                                       -0.299176  \
# 1                                       -0.301127
# 2                                       -0.247370
# 3                                       -0.296093
# 4                                       -0.292675
#
#    edited_3_books_3_512_6 - system_level_f1_BERT
# 0                                      -0.299887  \
# 1                                      -0.276901
# 2                                      -0.232738
# 3                                      -0.305271
# 4                                      -0.275539
#
#    edited_3_books_3_256_6 - system_level_f1_BERT
# 0                                      -0.314100  \
# 1                                      -0.303289
# 2                                      -0.263703
# 3                                      -0.265747
# 4                                      -0.298345
#
#    edited_3_books_3_128_6 - system_level_f1_BERT
# ...

# %%
fig, axs = plt.subplots(figsize=(6,7))
df_books_3.plot.line(ax=axs, style={'edited_3_books_3_1024_6 - system_level_f1_BERT':':C0',
                                'edited_3_books_3_512_6 - system_level_f1_BERT':':C1',
                                'edited_3_books_3_256_6 - system_level_f1_BERT':':C2',
                                'edited_3_books_3_128_6 - system_level_f1_BERT':':C3',
                                'normal_books_3_1024_6 - system_level_f1_BERT':'C0',
                                'normal_books_3_512_6 - system_level_f1_BERT':'C1',
                                'normal_books_3_256_6 - system_level_f1_BERT':'C2',
                                'normal_books_3_128_6 - system_level_f1_BERT':'C3'})
axs.set_ylabel("BERTScore")
axs.set_xlabel("Epochs")
axs.set_title("BERTScore for various hidden sizes")
axs.set_xlim(0, 49)
#axs.set_ylim(0, 13)
# Setup custom legend
# Guide: https://stackoverflow.com/questions/39500265/how-to-manually-create-a-legend
line = Line2D([0], [0], label='Default', linestyle='solid', color='k')
line_2 = Line2D([0], [0], label='Alternative', linestyle='dotted', color='k')
patch1 = mpatches.Patch(color='C0', label = '1024 hidden size')
patch2 = mpatches.Patch(color='C1', label = '512 hidden size')
patch3 = mpatches.Patch(color='C2', label = '256 hidden size')
patch4 = mpatches.Patch(color='C3', label = '128 hidden size')
handles, labels = fig.gca().get_legend_handles_labels()
#handles.extend([books_2_patch])
plt.legend(handles=[line, line_2, patch1, patch2, patch3, patch4])
fig.savefig("../../data/results/july_7_books_3_hidden_size.png",bbox_inches='tight')
plt.show()

# %%
df_books_3_ppl = pd.read_csv('../../data/results/july_7_results/books_3_ppl_hidden.csv')
df_books_3_ppl = df_books_3_ppl.drop('Step', axis=1)
df_books_3_ppl = df_books_3_ppl.iloc[:, [int(x) for x in range(0, 24, 3)]]

# %%
df_books_3_ppl.head()
# Out:
#    edited_3_books_3_1024_6 - ppl  edited_3_books_3_512_6 - ppl
# 0                  116755.601669                  77766.227514  \
# 1                    6809.232989                   6181.952349
# 2                    2562.214472                   2234.691261
# 3                    1333.738042                   1196.871734
# 4                     921.907427                    908.539843
#
#    edited_3_books_3_256_6 - ppl  edited_3_books_3_128_6 - ppl
# 0                  69730.115435                 101687.637856  \
# 1                  10021.988755                   6273.714154
# 2                   2224.106744                   2597.739247
# 3                   1295.022601                   1274.864744
# 4                    970.956476                    916.730577
#
#    normal_books_3_1024_6 - ppl  normal_books_3_512_6 - ppl
# 0                  5870.738697                 6101.413576  \
# 1                  1659.753344                 1869.271867
# ...

# %%
fig, axs = plt.subplots(figsize=(6,7))
df_books_3_ppl.plot.line(ax=axs, style={'edited_3_books_3_1024_6 - ppl':':C0',
                                'edited_3_books_3_512_6 - ppl':':C1',
                                'edited_3_books_3_256_6 - ppl':':C2',
                                'edited_3_books_3_128_6 - ppl':':C3',
                                'normal_books_3_1024_6 - ppl':'C0',
                                'normal_books_3_512_6 - ppl':'C1',
                                'normal_books_3_256_6 - ppl':'C2',
                                'normal_books_3_128_6 - ppl':'C3'})
axs.set_ylabel("Perplexity")
axs.set_xlabel("Epochs")
axs.set_title("Perplexity for various hidden sizes")
axs.set_xlim(0, 49)
#axs.set_ylim(0, 13)
plt.yscale("log")
axs.yaxis.set_major_formatter(ScalarFormatter())
# Setup custom legend
# Guide: https://stackoverflow.com/questions/39500265/how-to-manually-create-a-legend
line = Line2D([0], [0], label='Default', linestyle='solid', color='k')
line_2 = Line2D([0], [0], label='Alternative', linestyle='dotted', color='k')
patch1 = mpatches.Patch(color='C0', label = '1024 hidden size')
patch2 = mpatches.Patch(color='C1', label = '512 hidden size')
patch3 = mpatches.Patch(color='C2', label = '256 hidden size')
patch4 = mpatches.Patch(color='C3', label = '128 hidden size')
handles, labels = fig.gca().get_legend_handles_labels()
#handles.extend([books_2_patch])
plt.legend(handles=[line, line_2, patch1, patch2, patch3, patch4])
fig.savefig("../../data/results/july_7_books_3_hidden_size_ppl.png",bbox_inches='tight')
plt.show()

# %% [markdown]
# Combine into one graph

# %%
fig = plt.figure(figsize=(6,10))
gs = fig.add_gridspec(2, hspace=0)
axs = gs.subplots(sharex=True, sharey=False)

"""df_books_3_ppl.plot.line(ax=axs, style={'edited_3_books_3_1024_6 - ppl':':C0',
                                'edited_3_books_3_512_6 - ppl':':C1',
                                'edited_3_books_3_256_6 - ppl':':C2',
                                'edited_3_books_3_128_6 - ppl':':C3',
                                'normal_books_3_1024_6 - ppl':'C0',
                                'normal_books_3_512_6 - ppl':'C1',
                                'normal_books_3_256_6 - ppl':'C2',
                                'normal_books_3_128_6 - ppl':'C3'})"""
axs[0].plot(df_books_3_ppl['edited_3_books_3_1024_6 - ppl'], color='C0', linestyle=':')
axs[0].plot(df_books_3_ppl['edited_3_books_3_512_6 - ppl'], color='C1', linestyle=':')
axs[0].plot(df_books_3_ppl['edited_3_books_3_256_6 - ppl'], color='C2', linestyle=':')
axs[0].plot(df_books_3_ppl['edited_3_books_3_128_6 - ppl'], color='C3', linestyle=':')
axs[0].plot(df_books_3_ppl['normal_books_3_1024_6 - ppl'], color='C0', linestyle='-')
axs[0].plot(df_books_3_ppl['normal_books_3_512_6 - ppl'], color='C1', linestyle='-')
axs[0].plot(df_books_3_ppl['normal_books_3_256_6 - ppl'], color='C2', linestyle='-')
axs[0].plot(df_books_3_ppl['normal_books_3_128_6 - ppl'], color='C3', linestyle='-')
axs[0].set_xlim(0, 49)
axs[0].set_yscale("log")
axs[0].yaxis.set_major_formatter(ScalarFormatter())
axs[0].set_ylabel("Perplexity")

"""df_books_3.plot.line(ax=axs, style={'edited_3_books_3_1024_6 - system_level_f1_BERT':':C0',
                                'edited_3_books_3_512_6 - system_level_f1_BERT':':C1',
                                'edited_3_books_3_256_6 - system_level_f1_BERT':':C2',
                                'edited_3_books_3_128_6 - system_level_f1_BERT':':C3',
                                'normal_books_3_1024_6 - system_level_f1_BERT':'C0',
                                'normal_books_3_512_6 - system_level_f1_BERT':'C1',
                                'normal_books_3_256_6 - system_level_f1_BERT':'C2',
                                'normal_books_3_128_6 - system_level_f1_BERT':'C3'})"""
axs[1].plot(df_books_3['edited_3_books_3_1024_6 - system_level_f1_BERT'], color='C0', linestyle=':')
axs[1].plot(df_books_3['edited_3_books_3_512_6 - system_level_f1_BERT'], color='C1', linestyle=':')
axs[1].plot(df_books_3['edited_3_books_3_256_6 - system_level_f1_BERT'], color='C2', linestyle=':')
axs[1].plot(df_books_3['edited_3_books_3_128_6 - system_level_f1_BERT'], color='C3', linestyle=':')
axs[1].plot(df_books_3['normal_books_3_1024_6 - system_level_f1_BERT'], color='C0', linestyle='-')
axs[1].plot(df_books_3['normal_books_3_512_6 - system_level_f1_BERT'], color='C1', linestyle='-')
axs[1].plot(df_books_3['normal_books_3_256_6 - system_level_f1_BERT'], color='C2', linestyle='-')
axs[1].plot(df_books_3['normal_books_3_128_6 - system_level_f1_BERT'], color='C3', linestyle='-')
axs[1].set_xlim(0, 49)
axs[1].set_ylabel("BERTScore")
axs[1].set_xlabel("Epochs")

line = Line2D([0], [0], label='Default', linestyle='solid', color='k')
line_2 = Line2D([0], [0], label='Alternative', linestyle='dotted', color='k')
books_2_patch = mpatches.Patch(color='C0', label = '1024 hidden size')
books_3_patch = mpatches.Patch(color='C1', label = '512 hidden size')
books_6_patch = mpatches.Patch(color='C2', label = '256 hidden size')
reviews_patch = mpatches.Patch(color='C3', label = '128 hidden size')
handles, labels = fig.gca().get_legend_handles_labels()
#handles.extend([books_2_patch])
axs[0].legend(handles=[line, line_2, books_2_patch, books_3_patch, books_6_patch, reviews_patch])
axs[0].set_title("Perplexity and BERTScore for various hidden sizes on 'Books-3' dataset", wrap=True)
fig.savefig("../../data/results/july_7_books_3_sizes_full.png",bbox_inches='tight')
plt.show()
