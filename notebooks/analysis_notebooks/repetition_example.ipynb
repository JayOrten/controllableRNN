# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

# %%
df_rep = pd.read_csv('../../data/results/july_7_results/reviews_rep.csv')
df_rep = df_rep.drop('Step', axis=1)
df_rep = df_rep.iloc[:, [int(x) for x in range(0, 6, 3)]]

# %%
df_rep.head()
# Out:
#    edited_3_reviews_1024_8 - repitition  normal_reviews_1024_8 - repitition
# 0                              0.494282                            0.471703
# 1                              0.431235                            0.472752
# 2                              0.457641                            0.472947
# 3                              0.513993                            0.472112
# 4                              0.817816                            0.473458

# %%
fig, axs = plt.subplots(figsize=(5,4))
df_rep.plot.line(ax=axs, style={'edited_3_reviews_1024_8 - repitition':':C0',
                                'normal_reviews_1024_8 - repitition':'C0'})
axs.set_ylabel("Variation")
axs.set_xlabel("Epochs")
axs.set_title("Variation for models trained on Reviews data set")
axs.set_xlim(0, 49)
#axs.set_ylim(0, 13)
# Setup custom legend
# Guide: https://stackoverflow.com/questions/39500265/how-to-manually-create-a-legend
line = Line2D([0], [0], label='Default', linestyle='solid', color='C0')
line_2 = Line2D([0], [0], label='Alternative', linestyle='dotted', color='C0')
#books_2_patch = mpatches.Patch(color='C0', label = '8 Layers')
#books_3_patch = mpatches.Patch(color='C1', label = '6 Layers')
#books_6_patch = mpatches.Patch(color='C2', label = '4 Layers')
#reviews_patch = mpatches.Patch(color='C3', label = '2 Layers')
handles, labels = fig.gca().get_legend_handles_labels()
#handles.extend([books_2_patch])
plt.legend(handles=[line, line_2])

#axs.get_legend().remove()
fig.savefig("../../data/results/july_7_reviews_rep.png",bbox_inches='tight')
plt.show()
