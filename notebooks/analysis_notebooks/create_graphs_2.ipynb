# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

# %%
df_books_2 = pd.read_csv('../../data/results/july_7_results/books_2_loss.csv')

# %%
df_books_2.head()
# Out:
#    Step  edited_3_books_2_1024_8 - train_loss
# 0     4                             12.937713  \
# 1    10                             10.010153
# 2    16                              8.323774
# 3    22                              7.475589
# 4    28                              7.251974
#
#    edited_3_books_2_1024_8 - train_loss__MIN
# 0                                  12.937713  \
# 1                                  10.010153
# 2                                   8.323774
# 3                                   7.475589
# 4                                   7.251974
#
#    edited_3_books_2_1024_8 - train_loss__MAX
# 0                                  12.937713  \
# 1                                  10.010153
# 2                                   8.323774
# 3                                   7.475589
# 4                                   7.251974
#
#    edited_3_books_2_1024_6 - train_loss
# 0                             12.387125  \
# 1                             10.156720
# ...

# %%
df_books_2.shape
# Out:
# (50, 97)

# %%
# Drop pointless step column
df_books_2 = df_books_2.drop('Step', axis=1)

# %%
df_books_2
# Out:
#     edited_3_books_2_1024_8 - train_loss
# 0                              12.937713  \
# 1                              10.010153
# 2                               8.323774
# 3                               7.475589
# 4                               7.251974
# 5                               6.996570
# 6                               6.863999
# 7                               6.750920
# 8                               6.646477
# 9                               6.598563
# 10                              6.561315
# 11                              6.535859
# 12                              6.487515
# 13                              6.480153
# 14                              6.467222
# 15                              6.451993
# 16                              6.427902
# 17                              6.426786
# 18                              6.403213
# 19                              6.395241
# 20                              6.395236
# 21                              6.387600
# ...

# %%
# We want every third column
columns = [x for x in range(0, 96, 3)]
print(columns)
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93]

# %%
df_books_2 = df_books_2.iloc[:, [int(x) for x in range(0, 96, 3)]]

# %%
df_books_2.head()
# Out:
#    edited_3_books_2_1024_8 - train_loss  edited_3_books_2_1024_6 - train_loss
# 0                             12.937713                             12.387125  \
# 1                             10.010153                             10.156720
# 2                              8.323774                              9.003530
# 3                              7.475589                              7.730916
# 4                              7.251974                              7.186604
#
#    edited_3_books_2_1024_4 - train_loss  edited_3_books_2_1024_2 - train_loss
# 0                             12.487777                             12.310175  \
# 1                              9.804859                             10.645147
# 2                              8.912937                              8.811137
# 3                              7.812147                              7.869072
# 4                              7.432081                              7.539962
#
# ...

# %%
# For this chart, we want to average the loss values for all networks to compare edited vs default
# We'll start by splitting into two dataframes to work with
default_df_books_2 = df_books_2.iloc[:, 16:]
alternative_df_books_2 = df_books_2.iloc[:, :16]

# %%
# Average columns in both df
default_df_books_2['mean'] = default_df_books_2.mean(axis=1)
alternative_df_books_2['mean'] = alternative_df_books_2.mean(axis=1)
# Out:
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\2219948932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default_df_books_2['mean'] = default_df_books_2.mean(axis=1)
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\2219948932.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alternative_df_books_2['mean'] = alternative_df_books_2.mean(axis=1)

# %%
default_df_books_2.head()
# Out:
#    normal_books_2_1024_8 - train_loss  normal_books_2_1024_6 - train_loss
# 0                            9.145508                            9.340927  \
# 1                            7.887938                            7.831258
# 2                            7.554502                            7.530183
# 3                            7.148116                            7.273206
# 4                            7.058613                            7.193527
#
#    normal_books_2_1024_4 - train_loss  normal_books_2_1024_2 - train_loss
# 0                            9.075173                            9.283560  \
# 1                            8.075190                            7.584102
# 2                            7.651803                            7.145541
# 3                            7.264206                            6.784463
# 4                            7.073125                            6.448539
#
#    normal_books_2_512_8 - train_loss  normal_books_2_512_6 - train_loss
# ...

# %%
# Time to plot

# %%
fig, axs = plt.subplots(figsize=(5,3))
default_df_books_2['mean'].plot.line(ax=axs, style={'Mean':'C0'})
alternative_df_books_2['mean'].plot.line(ax=axs, style={'Mean':'C1'})
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss on 'Books-2' dataset")
axs.set_xlim(0, 49)
axs.set_ylim(0, 13)
plt.legend(['Default', 'Alternative'])
plt.show()

# %%
# Let's do that for all datasets, and then combine them into the same plot

# %%
df_books_3 = pd.read_csv('../../data/results/july_7_results/books_3_loss.csv')
df_books_3 = df_books_3.drop('Step', axis=1)
df_books_3 = df_books_3.iloc[:, [int(x) for x in range(0, 96, 3)]]
default_df_books_3 = df_books_3.iloc[:, 16:]
alternative_df_books_3 = df_books_3.iloc[:, :16]
default_df_books_3['mean'] = default_df_books_3.mean(axis=1)
alternative_df_books_3['mean'] = alternative_df_books_3.mean(axis=1)
# Out:
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\1602990274.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default_df_books_3['mean'] = default_df_books_3.mean(axis=1)
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\1602990274.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alternative_df_books_3['mean'] = alternative_df_books_3.mean(axis=1)

# %%
fig, axs = plt.subplots(figsize=(5,3))
default_df_books_3['mean'].plot.line(ax=axs, style={'Mean':'C0'})
alternative_df_books_3['mean'].plot.line(ax=axs, style={'Mean':'C1'})
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss on 'Books-3' dataset")
axs.set_xlim(0, 49)
axs.set_ylim(0, 13)
plt.legend(['Default', 'Alternative'])
plt.show()

# %%
df_books_6 = pd.read_csv('../../data/results/july_7_results/books_6_loss.csv')
df_books_6 = df_books_6.drop('Step', axis=1)
df_books_6 = df_books_6.iloc[:, [int(x) for x in range(0, 96, 3)]]
default_df_books_6 = df_books_6.iloc[:, 16:]
alternative_df_books_6 = df_books_6.iloc[:, :16]
default_df_books_6['mean'] = default_df_books_6.mean(axis=1)
alternative_df_books_6['mean'] = alternative_df_books_6.mean(axis=1)
# Out:
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\3072170872.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default_df_books_6['mean'] = default_df_books_6.mean(axis=1)
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\3072170872.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alternative_df_books_6['mean'] = alternative_df_books_6.mean(axis=1)

# %%
fig, axs = plt.subplots(figsize=(5,3))
default_df_books_6['mean'].plot.line(ax=axs, style={'Mean':'C0'})
alternative_df_books_6['mean'].plot.line(ax=axs, style={'Mean':'C1'})
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss on 'Books-6' dataset")
axs.set_xlim(0, 49)
axs.set_ylim(0, 13)
plt.legend(['Default', 'Alternative'])
plt.show()

# %%
df_scripts = pd.read_csv('../../data/results/july_7_results/scripts_loss.csv')
df_scripts = df_scripts.drop('Step', axis=1)
df_scripts = df_scripts.iloc[:, [int(x) for x in range(0, 96, 3)]]
default_df_scripts = df_scripts.iloc[:, 16:]
alternative_df_scripts = df_scripts.iloc[:, :16]
default_df_scripts['mean'] = default_df_scripts.mean(axis=1)
alternative_df_scripts['mean'] = alternative_df_scripts.mean(axis=1)
# Out:
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\3913131380.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default_df_scripts['mean'] = default_df_scripts.mean(axis=1)
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\3913131380.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alternative_df_scripts['mean'] = alternative_df_scripts.mean(axis=1)

# %%
fig, axs = plt.subplots(figsize=(5,3))
default_df_scripts['mean'].plot.line(ax=axs, style={'Mean':'C0'})
alternative_df_scripts['mean'].plot.line(ax=axs, style={'Mean':'C1'})
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss on 'Scripts' dataset")
axs.set_xlim(0, 49)
axs.set_ylim(0, 13)
plt.legend(['Default', 'Alternative'])
plt.show()

# %%
df_reviews = pd.read_csv('../../data/results/july_7_results/reviews_loss.csv')
df_reviews = df_reviews.drop('Step', axis=1)
df_reviews = df_reviews.iloc[:, [int(x) for x in range(0, 96, 3)]]
default_df_reviews = df_reviews.iloc[:, 16:]
alternative_df_reviews = df_reviews.iloc[:, :16]
default_df_reviews['mean'] = default_df_reviews.mean(axis=1)
alternative_df_reviews['mean'] = alternative_df_reviews.mean(axis=1)
# Out:
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\2892454043.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default_df_reviews['mean'] = default_df_reviews.mean(axis=1)
# C:\Users\jayor\AppData\Local\Temp\ipykernel_22064\2892454043.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alternative_df_reviews['mean'] = alternative_df_reviews.mean(axis=1)

# %%
fig, axs = plt.subplots(figsize=(5,3))
default_df_reviews['mean'].plot.line(ax=axs, style={'Mean':'C0'})
alternative_df_reviews['mean'].plot.line(ax=axs, style={'Mean':'C1'})
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss on 'Reviews' dataset")
axs.set_xlim(0, 49)
axs.set_ylim(0, 13)
plt.legend(['Default', 'Alternative'])
plt.show()

# %%
# All on the same chart
fig, axs = plt.subplots(figsize=(5,8))
default_df_books_2['mean'].plot.line(ax=axs, linestyle='solid', color='C0')
alternative_df_books_2['mean'].plot.line(ax=axs, linestyle='dashed', color='C0')
default_df_books_3['mean'].plot.line(ax=axs, linestyle='solid', color='C1')
alternative_df_books_3['mean'].plot.line(ax=axs, linestyle='dashed', color='C1')
default_df_books_6['mean'].plot.line(ax=axs, linestyle='solid', color='C2')
alternative_df_books_6['mean'].plot.line(ax=axs, linestyle='dashed', color='C2')
default_df_reviews['mean'].plot.line(ax=axs, linestyle='solid', color='C3')
alternative_df_reviews['mean'].plot.line(ax=axs, linestyle='dashed', color='C3')
default_df_scripts['mean'].plot.line(ax=axs, linestyle='solid', color='C4')
alternative_df_scripts['mean'].plot.line(ax=axs, linestyle='dashed', color='C4')
axs.set_ylabel("Batch Loss")
axs.set_xlabel("Epochs")
axs.set_title("Average training batch loss across all datasets")
axs.set_xlim(0, 49)
axs.set_ylim(4, 9)
# Setup custom legend
# Guide: https://stackoverflow.com/questions/39500265/how-to-manually-create-a-legend
line = Line2D([0], [0], label='Default', linestyle='solid', color='k')
line_2 = Line2D([0], [0], label='Alternative', linestyle='dashed', color='k')
books_2_patch = mpatches.Patch(color='C0', label = 'Books-2')
books_3_patch = mpatches.Patch(color='C1', label = 'Books-3')
books_6_patch = mpatches.Patch(color='C2', label = 'Books-6')
reviews_patch = mpatches.Patch(color='C3', label = 'Reviews')
scripts_patch = mpatches.Patch(color='C4', label = 'Scripts')
handles, labels = fig.gca().get_legend_handles_labels()
#handles.extend([books_2_patch])
plt.legend(handles=[line, line_2, books_2_patch, books_3_patch, books_6_patch, reviews_patch, scripts_patch])
fig.savefig("../../data/results/july_7_full_transformer_loss.png",bbox_inches='tight')
plt.show()
